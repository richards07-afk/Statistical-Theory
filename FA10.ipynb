# %% [markdown]
# <a href="https://colab.research.google.com/github/richards07-afk/Statistical-Theory/blob/main/FA10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X_simple = sm.add_constant(df['X2'])
model_simple = sm.OLS(Y, X_simple).fit()

plt.figure()
plt.scatter(df['X2'], Y)
plt.plot(df['X2'], model_simple.fittedvalues)
plt.xlabel('Departure Delay')
plt.ylabel('Arrival Delay')
plt.title('Regression Line (X2 vs Y)')
plt.show()
